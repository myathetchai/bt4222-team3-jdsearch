# %% [markdown]
# ## Import libraries

# %%
from google.colab import drive
import numpy as np
import pandas as pd
import os
from pathlib import Path
import glob

# %% [markdown]
# ## Extract data

# %%
# 1) Imports & mount
from google.colab import drive
drive.mount("/content/drive")

# 2) Paths
BASE = Path("/content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data")
PRODUCT_TXT = BASE / "product_meta_data.txt"
USER_TXT    = BASE / "user_behavior_data.txt"
CHUNKS_DIR  = BASE / "product_chunks"
CHUNKS_DIR.mkdir(parents=True, exist_ok=True)

# 3) Load small user data
user_df = pd.read_csv(USER_TXT, sep="\t", dtype=str, low_memory=False)
print("user_behaviour shape:", user_df.shape)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# user_behaviour shape: (173831, 7)

# %%
# 4) Stream big product TSV → parquet chunks
chunk_size = 200_000
for i, chunk in enumerate(pd.read_csv(PRODUCT_TXT, sep="\t", dtype=str, chunksize=chunk_size, low_memory=False)):
    out = CHUNKS_DIR / f"product_chunk_{i:05d}.parquet"
    chunk.to_parquet(out, index=False)
    print(f"Saved chunk {i} ({len(chunk)} rows)")

# %%
# 5) Read all product chunks as one dataframe
chunk_files = sorted(glob.glob(str(CHUNKS_DIR / "*.parquet")))
product_df = pd.concat([pd.read_parquet(f) for f in chunk_files], ignore_index=True)
print(product_df.shape)
# Out:
# (12141247, 13)

# %%
user_df.head()
# Out:
#                                                query  \
# 0                63995226602574196100244625575117
# 1                                  1254963427438884
# 2                          24374376067768939206305
# 3  29463948632095349356845164880503931105432...
# 4                           2793914964365783663289
#
#                                   candidate_wid_list  \
# 0  36098226_17729172_34921664_68317377_693764_360...
# 1  30857980_44577431_1485384_63372823_19754701_29...
# 2  42155506_90092899_4336287_74203839_39478459_37...
# 3  97234676_89827009_19973201_83859812_22172053_3...
# 4  19711065_83045333_8307571_20337381_11912759_53...
#
#                                 candidate_label_list  \
# 0  1.0_0.0_0.0_0.0_0.0_0.0_0.0_0.0_0.0_0.0_0.0_0....
# 1  1.0_1.0_0.0_0.0_0.0_0.0_0.0_0.0_0.0_0.0_0.0_0....
# 2  1.0_1.0_0.0_0.0_0.0_0.0_0.0_0.0_0.0_0.0_0.0_0....
# 3  1.0_0.0_0.0_0.0_0.0_0.0_0.0_0.0_0.0_0.0_0.0_0....
# 4  1.0_1.0_0.0_0.0_0.0_0.0_0.0_0.0_0.0_0.0_0.0_0....
#
#                                     history_qry_list  \
# 0  -1_-1_-1_68784030_36547097602574193663289_95...
# 1  9755613572694219_46916741_-1_-1_-1_-1_-1_4927...
# 2                                              -1_-1
# 3  3426234151020854598336931355834712920960_3...
# 4  25499566_24358647_606776896025741971768678_3...
#
#                                     history_wid_list  \
# 0  9227588_52788392_4585436_87422901_57364733_210...
# 1  18256630_46206270_65230659_86878921_32743602_5...
# 2                                   8133925_59478082
# 3  49854616_56947170_16552251_91485122_25087051_7...
# 4  68701_66196939_45800470_18419519_10090448_8073...
#
#                                    history_type_list  \
# 0  ORD_ORD_CART_CART_CART_CART_CART_CART_CART_CAR...
# 1  ORD_ORD_ORD_CART_CART_CART_CART_ORD_CART_CART_...
# 2                                        CLICK_CLICK
# 3  CLICK_CLICK_CLICK_CLICK_CLICK_CLICK_CLICK_CLIC...
# 4  ORD_ORD_ORD_ORD_ORD_ORD_ORD_ORD_ORD_ORD_ORD_OR...
#
#                                    history_time_list
# 0  0_0_22967659_82448_432_10315_51_188_51_254173_...
# 1  0_4813478_1115463_14061983_920_467229_304_1197...
# 2                                         0_27_49660
# 3  0_12_4_6_4_14_6_6_4_611_58095_1524_481_20_363_...
# 4  0_0_2015453_958482_0_79443_854291_13678_119386...

# %%
product_df.head()
# Out:
#         wid                                               name  brand_id  \
# 0  84303384  56009272602574199515329858899060608706386...  81493954
# 1  58965086  27823200249212549809550743221450974479927...  15444334
# 2  33811859  68082682602574199445877660257419536255837...  39479430
# 3  90290292  89270446755918046025741917635585029871926...  75019956
# 4  28171378  87851606417877054043879959056538602574195...  55412149
#
#                             brand_name cate_id_1        cate_name_1 cate_id_2  \
# 0                             56009272  22259905           44386912  80083037
# 1  27823200417877058264293359865766  68949654  7722037220300932  58682510
# 2                             68082682  22259905           44386912  80083037
# 3                    8927044675591804  75739187   176355875210311   9682321
# 4  87851606417877054043879959865766  44687275           47087603  38428440
#
#          cate_name_2 cate_id_3                cate_name_3 cate_id_4  \
# 0  2787702149701337  13599099          1902766526921156  50485737
# 1           20300932  37322654          9194357497447992  99504987
# 2  2787702149701337  93252909  20484919753274826921156  42385237
# 3   176355863043105  56674307                   50298719  65420542
# 4  7678748775210311  56166561          5803341578344560  60897751
#
#                  cate_name_4   shop_id
# 0          4746075788309887  86521100
# 1          9194357497447992   1462363
# 2  20484912257881342477615  86521100
# 3                   50298719   9644527
# 4          5803341578344560  60136421

# %% [markdown]
# ## Helper functions

# %%
def parse_candidate_list(candidate_str):
    """Parse candidate product IDs separated by underscores"""
    return candidate_str.split('_')

def parse_label_list(label_str):
    """Parse interaction labels as floats"""
    return [float(x) for x in label_str.split('_')]

def parse_history_queries(query_str):
    """Parse history query list, handling -1 for query-less interactions"""
    return query_str.split('_')

def parse_history_wids(wid_str):
    """Parse history product IDs"""
    return wid_str.split('_')

def parse_history_types(type_str):
    """Parse interaction types (ORD, CLICK, CART, etc.)"""
    return type_str.split('_')

def parse_time_list(time_str):
    """Parse time intervals as integers"""
    return [int(x) for x in time_str.split('_')]

# %% [markdown]
# ## Sampling #1: remove products which don't appear in either the candidate list or the history wid list

# %%
# 1) Build the needed ID set (strings)
cand_ids = {wid for s in user_df["candidate_wid_list"].dropna().astype(str)
            for wid in parse_candidate_list(s)}
hist_ids = {wid for s in user_df["history_wid_list"].dropna().astype(str)
            for wid in parse_history_wids(s)}
need_ids = cand_ids | hist_ids
print("unique needed wids:", len(need_ids))

# 2) Stream product chunks, filter, and write out
in_dir  = "/content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_chunks/*.parquet"
out_dir = Path("/content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered")
out_dir.mkdir(parents=True, exist_ok=True)

keep_cols = ["wid","name","brand_id","brand_name",
             "cate_id_1","cate_name_1","cate_id_2","cate_name_2",
             "cate_id_3","cate_name_3","cate_id_4","cate_name_4","shop_id"]

for i, f in enumerate(sorted(glob.glob(in_dir))):
    part = pd.read_parquet(f, columns=keep_cols)
    m = part["wid"].astype(str).isin(need_ids)
    if m.any():
        part.loc[m].to_parquet(out_dir / f"product_filtered_{i:05d}.parquet", index=False)
        print(f"✔ filtered -> {out_dir}/product_filtered_{i:05d}.parquet ({m.sum()} rows)")
    del part
print("Done (no big dataframe in RAM).")
# Out:
# unique needed wids: 12319978
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00000.parquet (190822 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00001.parquet (190830 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00002.parquet (190853 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00003.parquet (190822 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00004.parquet (190870 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00005.parquet (190947 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00006.parquet (190711 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00007.parquet (190769 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00008.parquet (190769 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00009.parquet (190936 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00010.parquet (190676 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00011.parquet (191057 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00012.parquet (190725 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00013.parquet (190959 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00014.parquet (190961 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00015.parquet (190892 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00016.parquet (191013 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00017.parquet (190954 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00018.parquet (190866 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00019.parquet (191086 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00020.parquet (190921 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00021.parquet (190855 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00022.parquet (190958 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00023.parquet (190879 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00024.parquet (190979 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00025.parquet (190997 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00026.parquet (190911 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00027.parquet (190759 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00028.parquet (190821 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00029.parquet (190956 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00030.parquet (191002 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00031.parquet (190864 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00032.parquet (190960 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00033.parquet (190813 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00034.parquet (190930 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00035.parquet (190743 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00036.parquet (190878 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00037.parquet (190822 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00038.parquet (190984 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00039.parquet (190704 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00040.parquet (190975 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00041.parquet (190977 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00042.parquet (191062 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00043.parquet (191142 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00044.parquet (190911 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00045.parquet (190872 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00046.parquet (190717 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00047.parquet (190894 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00048.parquet (190926 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00049.parquet (190910 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00050.parquet (190988 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00051.parquet (190873 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00052.parquet (190854 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00053.parquet (191022 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00054.parquet (190906 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00055.parquet (190939 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00056.parquet (190842 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00057.parquet (190870 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00058.parquet (190957 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00059.parquet (190867 rows)
# ✔ filtered -> /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/product_filtered_00060.parquet (134831 rows)
# Done (no big dataframe in RAM).

# %% [markdown]
# ## Sampling 2: Negative sampling
# For each query session, we retain all positive samples (label > 0) and randomly select a subset of negative samples with no interactions (label = 0) at a fixed ratio of 1:4 relative to the number of positives, discarding the remaining negatives. (candidate label list)
#
# Product metadata is joined only for products that survive this sampling; products without metadata are excluded.

# %%
# 1) Negative sampling per query (keep all positives + 1:4 sampled negatives)
rng = np.random.default_rng(42)  # reproducible

kept_wids = set()
sampled_rows = []

for wid_s, lab_s in user_df[["candidate_wid_list","candidate_label_list"]].itertuples(index=False):
    if not isinstance(wid_s, str) or not isinstance(lab_s, str):
        continue
    wids = parse_candidate_list(wid_s)
    labs = parse_label_list(lab_s)

    pos = [(w,l) for w,l in zip(wids,labs) if l > 0.0]
    neg = [(w,l) for w,l in zip(wids,labs) if l == 0.0]

    k = min(4*len(pos), len(neg))  # 1:4 pos:neg
    neg_sample = rng.choice(len(neg), size=k, replace=False).tolist() if k > 0 else []
    neg_keep = [neg[i] for i in neg_sample]

    kept = pos + neg_keep
    kept_wids.update(w for w,_ in kept)

    # build a compact sampled candidate list/labels row (as strings)
    if kept:
        sampled_rows.append((
            "_".join(w for w,_ in kept),
            "_".join(f"{l:g}" for _,l in kept)
        ))
    else:
        sampled_rows.append(("", ""))

print("unique kept product IDs after sampling:", len(kept_wids))

user_df_sampled = user_df.copy()
user_df_sampled[["candidate_wid_list","candidate_label_list"]] = pd.DataFrame(sampled_rows, index=user_df.index)
# Out:
# unique kept product IDs after sampling: 1269706

# %%
OUT_DIR = Path("/content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data")
OUT_DIR.mkdir(parents=True, exist_ok=True)

csv_path = OUT_DIR / "user_behavior_data_sampled.csv"
user_df_sampled.to_csv(csv_path, index=False)
print("saved:", csv_path)
# Out:
# saved: /content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/user_behavior_data_sampled.csv

# %%
# 2) Stream-filter product parquet chunks to only the sampled products
in_glob  = "/content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered/*.parquet"
out_dir = Path("/content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered2")
out_dir.mkdir(parents=True, exist_ok=True)

keep_cols = ["wid","name","brand_id","brand_name",
             "cate_id_1","cate_name_1","cate_id_2","cate_name_2",
             "cate_id_3","cate_name_3","cate_id_4","cate_name_4","shop_id"]

total = 0
for i, f in enumerate(sorted(glob.glob(in_glob))):
    part = pd.read_parquet(f, columns=keep_cols)
    m = part["wid"].astype(str).isin(kept_wids)
    if m.any():
        out_f = out_dir / f"product_sampled_{i:05d}.parquet"
        part.loc[m].to_parquet(out_f, index=False)
        total += m.sum()
        print(f"✔ {m.sum():,} kept -> {out_f.name}")
    del part
print("total sampled product rows written:", total)
# Out:
# ✔ 20,755 kept -> product_sampled_00000.parquet
# ✔ 20,795 kept -> product_sampled_00001.parquet
# ✔ 20,884 kept -> product_sampled_00002.parquet
# ✔ 20,731 kept -> product_sampled_00003.parquet
# ✔ 20,758 kept -> product_sampled_00004.parquet
# ✔ 20,827 kept -> product_sampled_00005.parquet
# ✔ 20,907 kept -> product_sampled_00006.parquet
# ✔ 20,581 kept -> product_sampled_00007.parquet
# ✔ 21,020 kept -> product_sampled_00008.parquet
# ✔ 20,942 kept -> product_sampled_00009.parquet
# ✔ 20,903 kept -> product_sampled_00010.parquet
# ✔ 20,705 kept -> product_sampled_00011.parquet
# ✔ 20,787 kept -> product_sampled_00012.parquet
# ✔ 20,626 kept -> product_sampled_00013.parquet
# ✔ 20,676 kept -> product_sampled_00014.parquet
# ✔ 20,727 kept -> product_sampled_00015.parquet
# ✔ 20,809 kept -> product_sampled_00016.parquet
# ✔ 20,783 kept -> product_sampled_00017.parquet
# ✔ 20,802 kept -> product_sampled_00018.parquet
# ✔ 20,736 kept -> product_sampled_00019.parquet
# ✔ 20,946 kept -> product_sampled_00020.parquet
# ✔ 20,879 kept -> product_sampled_00021.parquet
# ✔ 20,820 kept -> product_sampled_00022.parquet
# ✔ 20,782 kept -> product_sampled_00023.parquet
# ✔ 20,877 kept -> product_sampled_00024.parquet
# ✔ 20,666 kept -> product_sampled_00025.parquet
# ✔ 20,837 kept -> product_sampled_00026.parquet
# ✔ 20,831 kept -> product_sampled_00027.parquet
# ✔ 20,876 kept -> product_sampled_00028.parquet
# ✔ 20,980 kept -> product_sampled_00029.parquet
# ✔ 21,150 kept -> product_sampled_00030.parquet
# ✔ 20,825 kept -> product_sampled_00031.parquet
# ✔ 20,851 kept -> product_sampled_00032.parquet
# ✔ 20,679 kept -> product_sampled_00033.parquet
# ✔ 20,984 kept -> product_sampled_00034.parquet
# ✔ 20,796 kept -> product_sampled_00035.parquet
# ✔ 20,907 kept -> product_sampled_00036.parquet
# ✔ 20,859 kept -> product_sampled_00037.parquet
# ✔ 20,676 kept -> product_sampled_00038.parquet
# ✔ 20,636 kept -> product_sampled_00039.parquet
# ✔ 20,718 kept -> product_sampled_00040.parquet
# ✔ 20,841 kept -> product_sampled_00041.parquet
# ✔ 20,914 kept -> product_sampled_00042.parquet
# ✔ 20,784 kept -> product_sampled_00043.parquet
# ✔ 20,770 kept -> product_sampled_00044.parquet
# ✔ 20,906 kept -> product_sampled_00045.parquet
# ✔ 21,093 kept -> product_sampled_00046.parquet
# ✔ 20,884 kept -> product_sampled_00047.parquet
# ✔ 20,916 kept -> product_sampled_00048.parquet
# ✔ 20,928 kept -> product_sampled_00049.parquet
# ✔ 20,846 kept -> product_sampled_00050.parquet
# ✔ 20,686 kept -> product_sampled_00051.parquet
# ✔ 20,797 kept -> product_sampled_00052.parquet
# ✔ 20,744 kept -> product_sampled_00053.parquet
# ✔ 20,897 kept -> product_sampled_00054.parquet
# ✔ 20,700 kept -> product_sampled_00055.parquet
# ✔ 20,674 kept -> product_sampled_00056.parquet
# ✔ 20,788 kept -> product_sampled_00057.parquet
# ✔ 20,670 kept -> product_sampled_00058.parquet
# ✔ 20,694 kept -> product_sampled_00059.parquet
# ✔ 14,568 kept -> product_sampled_00060.parquet
# total sampled product rows written: 1263429

# %% [markdown]
# ## Load into df and conduct simple data analysis

# %%
PROD_DIR = Path("/content/drive/MyDrive/BT4222 Group 3/1. Data Preparation/Data/product_filtered2")

product_df = pd.read_parquet(PROD_DIR, columns=keep_cols, dtype_backend="pyarrow")

print(product_df.shape)
product_df.head()
# Out:
# (1263429, 13)
#         wid                                               name  brand_id  \
# 0  90290292  89270446755918046025741917635585029871926...  75019956
# 1  84294794  35314470278253305644862259056538602574191...  90358683
# 2  43985934  99002012107475224750389807345717281391786...  99906610
# 3  58357343  37269793566964962025051838249885733255404...  67566476
# 4  71803457  53536632602574194190735260257419201104367...  78161242
#
#                             brand_name cate_id_1                 cate_name_1  \
# 0                    8927044675591804  75739187            176355875210311
# 1                             56448622    920973  413810773160222581402210
# 2                             99002012  24675518           2053319081620728
# 3  37269793417877055669649659865766  98432384   49629523385795642329532
# 4  53536632417877055360263159865766   6867541                    50134995
#
#   cate_id_2        cate_name_2 cate_id_3                          cate_name_3  \
# 0   9682321   176355863043105  56674307                             50298719
# 1  72011611  4138107765056023  77105805                    2883009146686422
# 2  45178979   976474541190979  41488568  10747522807345713385795688352935
# 3  78943759           42329532  84880674                             25517595
# 4  47765755   290298641345793  66118678                             41907352
#
#   cate_id_4                          cate_name_4   shop_id
# 0  65420542                             50298719   9644527
# 1  14729718                    2883009146686422  51346695
# 2   8059148  10747522807345713385795688352935  71737804
# 3  16697032                             25517595  45062963
# 4  70549743                             41907352  24505854

# %%
# No. of unique products
print(f"No. of unique products: {product_df["wid"].nunique()}")

# Top categories
print(product_df["cate_name_1"].value_counts().head(10))

# Missingness overview
product_df.isna().mean().sort_values(ascending=False).head(10)
# Out:
# No. of unique products: 1263429
# cate_name_1
# 413810773160222581402210    101657
# 7722037220300932              90590
# 223100                         89302
# 3153887681590330              85364
# 4338732011476273              78669
# 9483389095217261              60256
# 5905495980470873              59222
# 80488822                       56203
# 163221                         46355
# 5889945488456828              42290
# Name: count, dtype: int64[pyarrow]
# brand_name     0.062578
# wid            0.000000
# name           0.000000
# brand_id       0.000000
# cate_id_1      0.000000
# cate_name_1    0.000000
# cate_id_2      0.000000
# cate_name_2    0.000000
# cate_id_3      0.000000
# cate_name_3    0.000000
# dtype: float64
